# %% [markdown]
# #### This notebook contains tests for checking the runtime of spectral generation algorithms. It contains tests for comparing runtimes between different versions of Mars.

# %%
# %load_ext autoreload
# %autoreload 2

import sys
import os
import typing as tp
import math
from importlib import reload

import torch
from torch import nn
import numpy as np
import matplotlib.pyplot as plt

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..', '..')))

import time
import torch
import numpy as np
import matplotlib.pyplot as plt
from typing import Optional, Union, Tuple, List
from mars import spin_model, spectra_manager, mesher, constants

from sample_creators import (create_2_electrons_sample, create_3_electrons_sample, 
                             create_4_electrons_sample, create_2_electrons_1_nuclei_sample,
                             create_1_high_spin_electron_1_nuclei_sample\
                            )

from saving_benchmarks import save_benchmark_results, load_benchmark_results

from bencmarking import benchmark_several_configurations, compare_benchmarks, plot_benchmark_comparison
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np

# %%
config_creators = {
    "2e": ("Two electrons", create_2_electrons_sample),
    "3e": ("Three electrons", create_3_electrons_sample),
    "2e_1n": ("Two electrons + one nucleus", create_2_electrons_1_nuclei_sample),
}

mesh_configs = [(20, 21), (20, 30), (20, 40)]
#mesh_configs = [(20, 20)]
#mesh_configs = [(4, 5),]
results_analytical_formula = benchmark_several_configurations(config_creators=config_creators, mesh_configs=mesh_configs,
                                                                 dtype=torch.float32, device = torch.device("cpu"))
# Out:
# Benchmarking on CPU with torch.float32
# ======================================================================
#
# Two electrons (Hilbert dim: 4)
#   Mesh 20x21        ...   19.06 ±  1.09 ms (192 orientations)
#   Mesh 20x30        ...   22.40 ±  1.07 ms (192 orientations)
#   Mesh 20x40        ...   28.50 ±  1.29 ms (192 orientations)
#
# Three electrons (Hilbert dim: 8)
#   Mesh 20x21        ...   38.91 ±  0.54 ms (192 orientations)
#   Mesh 20x30        ...   46.59 ±  1.76 ms (192 orientations)
#   Mesh 20x40        ...   72.07 ±  6.19 ms (192 orientations)
#
# Two electrons + one nucleus (Hilbert dim: Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "C:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\mars\particles\typed_particles.py", line 127, in _load_isotope_data
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\User\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\mars\\particles\\nuclei_db\\nuclear_data.pkl'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\interactiveshell.py", line 3460, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_25764\2950324319.py", line 10, in <module>
#     results_analytical_formula = benchmark_several_configurations(config_creators=config_creators, mesh_configs=mesh_configs,
#   File "D:\ITC\РНФ_Курганский_2024\pythonProject\MarS\tests\time_tests\bencmarking.py", line 362, in benchmark_several_configurations
#     test_sample = creator_func(mesh=mesh_configs[0], device=device, dtype=dtype)
#   File "D:\ITC\РНФ_Курганский_2024\pythonProject\MarS\tests\time_tests\sample_creators.py", line 231, in create_2_electrons_1_nuclei_sample
#     spin_sys = spin_model.SpinSystem(
#   File "C:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\mars\spin_model.py", line 1263, in __init__
#   File "C:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\mars\spin_model.py", line 1346, in _init_nuclei
#   File "C:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\mars\spin_model.py", line 1346, in <listcomp>
#   File "C:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\mars\spin_model.py", line 1341, in _convert
#   File "C:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\mars\particles\typed_particles.py", line 116, in __init__
#   File "C:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\mars\particles\typed_particles.py", line 131, in _load_isotope_data
# FileNotFoundError: Isotope data file 'C:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\mars\particles\nuclei_db\nuclear_data.pkl' not found.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\interactiveshell.py", line 2057, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#   File "C:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\ultratb.py", line 1288, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "C:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\ultratb.py", line 1177, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "C:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\ultratb.py", line 1049, in structured_traceback
#     formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#   File "C:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\ultratb.py", line 935, in format_exception_as_a_whole
#     self.get_records(etb, number_of_lines_of_context, tb_offset) if etb else []
#   File "C:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\ultratb.py", line 1003, in get_records
#     lines, first = inspect.getsourcelines(etb.tb_frame)
#   File "C:\Users\User\AppData\Local\Programs\Python\Python310\lib\inspect.py", line 1129, in getsourcelines
#     lines, lnum = findsource(object)
#   File "C:\Users\User\AppData\Local\Programs\Python\Python310\lib\inspect.py", line 958, in findsource
#     raise OSError('could not get source code')
# OSError: could not get source code

# %%
results_initial = load_benchmark_results("time_test_results/run_20260205_interpolation_before_changes")

# %%
compare_benchmarks([results_initial["results"], results_analytical_formula])
# Out:
# {'summary':                                                   mean_time_ms_mean
#  system_key mesh_resolution hilbert_dim mesh_size
#  2e         20x21           4           192                    25.50  \
#                                         210                    19.52
#             20x30           4           192                    29.94
#                                         210                    22.26
#             20x40           4           192                    40.52
#                                         210                    23.91
#  2e_1n      20x21           12          192                    89.95
#                                         210                    56.61
#             20x30           12          192                   155.41
#                                         210                    86.82
#             20x40           12          192                   259.18
#                                         210                   150.19
#  3e         20x21           8           192                    51.01
#                                         210                    36.34
#             20x30           8           192                    71.64
#                                         210                    46.47
#             20x40           8           192                   114.92
#                                         210                    62.60
#
#                                                    mean_time_ms_std
#  system_key mesh_resolution hilbert_dim mesh_size
#  2e         20x21           4           192                     NaN  \
#                                         210                     NaN
#             20x30           4           192                     NaN
#                                         210                     NaN
#             20x40           4           192                     NaN
#                                         210                     NaN
#  2e_1n      20x21           12          192                     NaN
#                                         210                     NaN
#             20x30           12          192                     NaN
#                                         210                     NaN
#             20x40           12          192                     NaN
#                                         210                     NaN
#  3e         20x21           8           192                     NaN
#                                         210                     NaN
#             20x30           8           192                     NaN
#                                         210                     NaN
#             20x40           8           192                     NaN
#                                         210                     NaN
#
#                                                    mean_time_ms_min
#  system_key mesh_resolution hilbert_dim mesh_size
#  2e         20x21           4           192                   25.50  \
#                                         210                   19.52
#             20x30           4           192                   29.94
#                                         210                   22.26
#             20x40           4           192                   40.52
#                                         210                   23.91
#  2e_1n      20x21           12          192                   89.95
#                                         210                   56.61
#             20x30           12          192                  155.41
#                                         210                   86.82
#             20x40           12          192                  259.18
#                                         210                  150.19
#  3e         20x21           8           192                   51.01
#                                         210                   36.34
#             20x30           8           192                   71.64
#                                         210                   46.47
#             20x40           8           192                  114.92
#                                         210                   62.60
#
#                                                    mean_time_ms_max
#  system_key mesh_resolution hilbert_dim mesh_size
#  2e         20x21           4           192                   25.50  \
#                                         210                   19.52
#             20x30           4           192                   29.94
#                                         210                   22.26
#             20x40           4           192                   40.52
#                                         210                   23.91
#  2e_1n      20x21           12          192                   89.95
#                                         210                   56.61
#             20x30           12          192                  155.41
#                                         210                   86.82
#             20x40           12          192                  259.18
#                                         210                  150.19
#  3e         20x21           8           192                   51.01
#                                         210                   36.34
#             20x30           8           192                   71.64
#                                         210                   46.47
#             20x40           8           192                  114.92
#                                         210                   62.60
#
#                                                    std_time_ms_mean
#  system_key mesh_resolution hilbert_dim mesh_size
#  2e         20x21           4           192                    1.21
#                                         210                    0.84
#             20x30           4           192                    0.65
#                                         210                    2.16
#             20x40           4           192                    1.72
#                                         210                    1.33
#  2e_1n      20x21           12          192                    2.13
#                                         210                    0.64
#             20x30           12          192                    2.09
#                                         210                    1.48
#             20x40           12          192                    5.34
#                                         210                   27.16
#  3e         20x21           8           192                    1.16
#                                         210                    0.82
#             20x30           8           192                    1.74
#                                         210                    1.10
#             20x40           8           192                    4.38
#                                         210                    1.04  ,
#  'speedups': {'run0_vs_run1': {('2e', '20x21'): 0.7655737653435088,
#    ('2e', '20x30'): 0.7437003401483641,
#    ('2e', '20x40'): 0.5900832042751344,
#    ('3e', '20x21'): 0.7124239509925737,
#    ('3e', '20x30'): 0.648670930978188,
#    ('3e', '20x40'): 0.5447491002315735,
#    ('2e_1n', '20x21'): 0.6293901319764548,
#    ('2e_1n', '20x30'): 0.5586670003678149,
#    ('2e_1n', '20x40'): 0.5794773858787216}},
#  'raw':     run system_key                 system_label mesh_resolution  mesh_size
#  0     0         2e                Two electrons           20x21        210  \
#  1     0         2e                Two electrons           20x30        210
#  2     0         2e                Two electrons           20x40        210
#  3     0         3e              Three electrons           20x21        210
#  4     0         3e              Three electrons           20x30        210
#  5     0         3e              Three electrons           20x40        210
#  6     0      2e_1n  Two electrons + one nucleus           20x21        210
#  7     0      2e_1n  Two electrons + one nucleus           20x30        210
#  8     0      2e_1n  Two electrons + one nucleus           20x40        210
#  9     1         2e                Two electrons           20x21        192
#  10    1         2e                Two electrons           20x30        192
#  11    1         2e                Two electrons           20x40        192
#  12    1         3e              Three electrons           20x21        192
#  13    1         3e              Three electrons           20x30        192
#  14    1         3e              Three electrons           20x40        192
#  15    1      2e_1n  Two electrons + one nucleus           20x21        192
#  16    1      2e_1n  Two electrons + one nucleus           20x30        192
#  17    1      2e_1n  Two electrons + one nucleus           20x40        192
#
#      hilbert_dim  mean_time_ms  std_time_ms
#  0             4     19.523310     0.844679
#  1             4     22.263960     2.163626
#  2             4     23.908115     1.333602
#  3             8     36.338295     0.818877
#  4             8     46.472125     1.100962
#  5             8     62.601695     1.035823
#  6            12     56.611600     0.642830
#  7            12     86.819810     1.483492
#  8            12    150.190470    27.156907
#  9             4     25.501540     1.214652
#  10            4     29.936735     0.648703
#  11            4     40.516515     1.724343
#  12            8     51.006560     1.158442
#  13            8     71.642065     1.736969
#  14            8    114.918400     4.379717
#  15           12     89.946755     2.125875
#  16           12    155.405295     2.090336
#  17           12    259.182625     5.342720  }

# %%
config_creators = {
    "2e": ("Two electrons", create_2_electrons_sample),
    "3e": ("Three electrons", create_3_electrons_sample),
    "4e": ("Four electrons", create_4_electrons_sample),
    "2e_1n": ("Two electrons + one nucleus", create_2_electrons_1_nuclei_sample),
    "high_spin": ("High-spin Mn(II)", create_1_high_spin_electron_1_nuclei_sample),
}

# %%
import torch
import timeit

# Setup: create a large tensor on CPU (you can move to CUDA if available)
device = 'cpu'  # or 'cuda' if you want GPU timing
x = torch.randn(10_000_000, device=device)

# Define callables
def run_erf():
    return torch.erf(x)

def run_exp():
    return torch.exp(x)

# Time each function (number of repeats can be adjusted)
n_runs = 1000

time_erf = timeit.timeit(run_erf, number=n_runs)
time_exp = timeit.timeit(run_exp, number=n_runs)

print(f"torch.erf: {time_erf:.4f} s over {n_runs} runs")
print(f"torch.exp: {time_exp:.4f} s over {n_runs} runs")
print(f"Ratio (erf/exp): {time_erf / time_exp:.2f}")
# Out:
# torch.erf: 5.4448 s over 1000 runs
# torch.exp: 4.6081 s over 1000 runs
# Ratio (erf/exp): 1.18
