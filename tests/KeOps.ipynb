# %%
from pykeops.torch import tensor as K
x = K( torch.randn(10**6, 1, 3) )
y = K( torch.randn(1, 10**7, 3) )
b = K( torch.randn(1, 10**7, 2) )
# Out:
# [KeOps] Warning : No C++ compiler found. Define CXX environment variable or install g++.
# [KeOps] Warning : No C++ compiler found. You need to either define the CXX environment variable pointing to a valid compiler, or ensure that 'g++' is installed and in your PATH.
# [KeOps] Warning : CUDA libraries not found or could not be loaded; Switching to CPU only.
# [KeOps] Warning : No C++ compiler found. You need to either define the CXX environment variable pointing to a valid compiler, or ensure that 'g++' is installed and in your PATH.
# [KeOps] Warning : No C++ compiler available to check for OpenMP support.
# [KeOps] Warning : OpenMP support is not available. Disabling OpenMP.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from pykeops.torch import tensor as K
#       2 x = K( torch.randn(10**6, 1, 3) )
#       3 y = K( torch.randn(1, 10**7, 3) )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pykeops\__init__.py:101
#      97     return keops_get_build_folder()
#     100 if numpy_found:
# --> 101     from .numpy.test_install import test_numpy_bindings
#     103 if torch_found:
#     104     from .torch.test_install import test_torch_bindings
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pykeops\numpy\__init__.py:5
#       1 ##########################################################
#       2 # Import pyKeOps routines
# ----> 5 from .generic.generic_red import Genred
#       7 # from .generic.generic_red_R import GenredR # FIXME
#       8 from .operations import KernelSolve
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pykeops\numpy\generic\generic_red.py:4
#       1 import numpy as np
#       3 from pykeops.common.get_options import get_tag_backend
# ----> 4 from pykeops.common.operations import preprocess, postprocess
#       5 from pykeops.common.parse_type import get_sizes, complete_aliases, get_optional_flags
#       6 from pykeops.common.utils import axis2cat
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pykeops\common\operations.py:3
#       1 import numpy as np
# ----> 3 from pykeops.common.utils import get_tools
#       6 # Some advance operations defined at user level use in fact other reductions.
#       7 def preprocess(reduction_op, formula2):
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pykeops\common\utils.py:1
# ----> 1 import fcntl
#       2 import functools
#       3 import importlib.util
#
# ModuleNotFoundError: No module named 'fcntl'
